# %%
import os
from googletrans import Translator

# %%
# Extract Texts from Folders
def read_files_from_directory(reviews_path):
    reviews = []
    for filename in os.listdir(reviews_path):
        if filename.endswith(".txt"):
            with open(os.path.join(reviews_path, filename), 'r', encoding='ISO-8859-1') as file:
                reviews.append(file.read())
    return reviews

# %%
# Define the paths to the positive and negative reviews
pos_reviews_path = r'D:\Gethub\Sentiment-Analysis-of-Movie-Reviews\Dataset\pos'
neg_reviews_path = r'D:\Gethub\Sentiment-Analysis-of-Movie-Reviews\Dataset\neg'
# Read the positive and negative reviews
pos_reviews = read_files_from_directory(pos_reviews_path)
neg_reviews = read_files_from_directory(neg_reviews_path)

# %%
# Data Augmentation By Back Translation
def back_translate(texts, target_language='fr', source_language='en', max_chunk_size=4000):
    # Initialize a list to store all texts
    all_texts = []
    # Initialize the translator
    translator = Translator()
    
    # Loop through all the texts
    for i, text in enumerate(texts):
        # Append the original text to the list
        all_texts.append(text)
        # If the text length exceeds the maximum chunk size, split it into smaller chunks
        if len(text) > max_chunk_size:
            chunks = [text[j:j+max_chunk_size] for j in range(0, len(text), max_chunk_size)]
            print(f"Text number {i + 1} was splited into {len(chunks)} chunks.")
        else:
            chunks = [text]
        
        # Initialize a list to store translated chunks
        translated_chunks = []
        
        # Translate each chunk individually
        for j, chunk in enumerate(chunks):
            try:
                # Translate the chunk to the target language
                translated_chunk = translator.translate(chunk, dest=target_language).text
                # Translate the translated chunk back to the original language
                back_translated_chunk = translator.translate(translated_chunk, dest=source_language).text
                # Append the back translated chunk to the list
                translated_chunks.append(back_translated_chunk)
            except Exception as e:
                print(f"Error occurred for chunck number {j + 1}: {e}")
        
        # Combine the translated chunks and append them to the list
        combined_text = ' '.join(translated_chunks)
        all_texts.append(combined_text)
        print(f"Text number {i + 1} is done.")
    
    return all_texts

# %%
print("Lenght Of Positive Reviews Before Augmentation: ", len(pos_reviews))
print("Lenght Of Negative Reviews Before Augmentation: ", len(neg_reviews))
pos_reviews = back_translate(pos_reviews)
neg_reviews = back_translate(neg_reviews)
print("Lenght Of Positive Reviews After Augmentation: ", len(pos_reviews))
print("Lenght Of Negative Reviews Before Augmentation: ", len(neg_reviews))
# Out:
# Lenght Of Positive Reviews Before Augmentation:  1000
# Lenght Of Negative Reviews Before Augmentation:  1000
# Text number 1 was splited into 2 chunks.
# Text number 1 is done.
# Text number 2 was splited into 2 chunks.
# Text number 2 is done.
# Text number 3 is done.
# Text number 4 was splited into 2 chunks.
# Text number 4 is done.
# Text number 5 is done.
# Text number 6 was splited into 2 chunks.
# Text number 6 is done.
# Text number 7 was splited into 2 chunks.
# Text number 7 is done.
# Text number 8 is done.
# Text number 9 is done.
# Text number 10 is done.
# Text number 11 was splited into 2 chunks.
# Text number 11 is done.
# Text number 12 was splited into 2 chunks.
# Text number 12 is done.
# Text number 13 is done.
# Text number 14 is done.
# Text number 15 was splited into 2 chunks.
# Text number 15 is done.
# Text number 16 is done.
# Text number 17 is done.
# Text number 18 was splited into 2 chunks.
# Text number 18 is done.
# Text number 19 is done.
# Text number 20 is done.
# Text number 21 is done.
# Text number 22 is done.
# Text number 23 is done.
# Text number 24 was splited into 2 chunks.
# Text number 24 is done.
# Text number 25 was splited into 2 chunks.
# Text number 25 is done.
# Text number 26 was splited into 2 chunks.
# Text number 26 is done.
# Text number 27 is done.
# Text number 28 was splited into 2 chunks.
# Text number 28 is done.
# Text number 29 was splited into 2 chunks.
# Text number 29 is done.
# Text number 30 was splited into 2 chunks.
# Text number 30 is done.
# Text number 31 was splited into 2 chunks.
# Text number 31 is done.
# Text number 32 was splited into 2 chunks.
# Text number 32 is done.
# Text number 33 was splited into 2 chunks.
# Text number 33 is done.
# Text number 34 was splited into 2 chunks.
# Text number 34 is done.
# Text number 35 is done.
# Text number 36 is done.
# Text number 37 is done.
# Text number 38 was splited into 2 chunks.
# Text number 38 is done.
# Text number 39 is done.
# Text number 40 is done.
# Text number 41 is done.
# Text number 42 was splited into 2 chunks.
# Text number 42 is done.
# Text number 43 was splited into 2 chunks.
# Text number 43 is done.
# Text number 44 is done.
# Text number 45 was splited into 2 chunks.
# Text number 45 is done.
# Text number 46 was splited into 2 chunks.
# Text number 46 is done.
# Text number 47 was splited into 2 chunks.
# Text number 47 is done.
# Text number 48 is done.
# Text number 49 is done.
# Text number 50 is done.
# Text number 51 is done.
# Text number 52 is done.
# Text number 53 is done.
# Text number 54 was splited into 2 chunks.
# Text number 54 is done.
# Text number 55 is done.
# Text number 56 was splited into 2 chunks.
# Text number 56 is done.
# Text number 57 is done.
# Text number 58 is done.
# Text number 59 is done.
# Text number 60 was splited into 2 chunks.
# Text number 60 is done.
# Text number 61 was splited into 2 chunks.
# Text number 61 is done.
# Text number 62 is done.
# Text number 63 was splited into 2 chunks.
# Text number 63 is done.
# Text number 64 is done.
# Text number 65 was splited into 2 chunks.
# Text number 65 is done.
# Text number 66 was splited into 2 chunks.
# Text number 66 is done.
# Text number 67 is done.
# Text number 68 is done.
# Text number 69 was splited into 2 chunks.
# Text number 69 is done.
# Text number 70 is done.
# Text number 71 is done.
# Text number 72 was splited into 2 chunks.
# Text number 72 is done.
# Text number 73 is done.
# Text number 74 was splited into 2 chunks.
# Text number 74 is done.
# Text number 75 was splited into 3 chunks.
# Text number 75 is done.
# Text number 76 is done.
# Text number 77 was splited into 2 chunks.
# Text number 77 is done.
# Text number 78 is done.
# Text number 79 is done.
# Text number 80 is done.
# Text number 81 is done.
# Text number 82 is done.
# Text number 83 is done.
# Text number 84 was splited into 2 chunks.
# Text number 84 is done.
# Text number 85 was splited into 2 chunks.
# Text number 85 is done.
# Text number 86 was splited into 2 chunks.
# Text number 86 is done.
# Text number 87 was splited into 2 chunks.
# Text number 87 is done.
# Text number 88 was splited into 2 chunks.
# Text number 88 is done.
# Text number 89 is done.
# Text number 90 is done.
# Text number 91 is done.
# Text number 92 is done.
# Text number 93 was splited into 2 chunks.
# Text number 93 is done.
# Text number 94 is done.
# Text number 95 is done.
# Text number 96 is done.
# Text number 97 was splited into 2 chunks.
# Text number 97 is done.
# Text number 98 was splited into 2 chunks.
# Text number 98 is done.
# Text number 99 is done.
# Text number 100 was splited into 2 chunks.
# Text number 100 is done.
# Text number 101 is done.
# Text number 102 was splited into 2 chunks.
# Text number 102 is done.
# Text number 103 is done.
# Text number 104 was splited into 2 chunks.
# Text number 104 is done.
# Text number 105 is done.
# Text number 106 was splited into 2 chunks.
# Text number 106 is done.
# Text number 107 is done.
# Text number 108 is done.
# Text number 109 is done.
# Text number 110 was splited into 2 chunks.
# Text number 110 is done.
# Text number 111 was splited into 2 chunks.
# Text number 111 is done.
# Text number 112 is done.
# Text number 113 was splited into 2 chunks.
# Text number 113 is done.
# Text number 114 was splited into 2 chunks.
# Text number 114 is done.
# Text number 115 is done.
# Text number 116 was splited into 2 chunks.
# Text number 116 is done.
# Text number 117 was splited into 2 chunks.
# Text number 117 is done.
# Text number 118 was splited into 2 chunks.
# Text number 118 is done.
# Text number 119 is done.
# Text number 120 is done.
# Text number 121 was splited into 2 chunks.
# Text number 121 is done.
# Text number 122 was splited into 2 chunks.
# Text number 122 is done.
# Text number 123 was splited into 3 chunks.
# Text number 123 is done.
# Text number 124 was splited into 2 chunks.
# Text number 124 is done.
# Text number 125 is done.
# Text number 126 is done.
# Text number 127 was splited into 2 chunks.
# Text number 127 is done.
# Text number 128 is done.
# Text number 129 is done.
# Text number 130 is done.
# Text number 131 is done.
# Text number 132 was splited into 2 chunks.
# Text number 132 is done.
# Text number 133 is done.
# Text number 134 is done.
# Text number 135 is done.
# Text number 136 is done.
# Text number 137 was splited into 2 chunks.
# Text number 137 is done.
# Text number 138 is done.
# Text number 139 is done.
# Text number 140 is done.
# Text number 141 was splited into 2 chunks.
# Text number 141 is done.
# Text number 142 was splited into 2 chunks.
# Text number 142 is done.
# Text number 143 is done.
# Text number 144 was splited into 2 chunks.
# Text number 144 is done.
# Text number 145 is done.
# Text number 146 is done.
# Text number 147 was splited into 3 chunks.
# Text number 147 is done.
# Text number 148 was splited into 2 chunks.
# Text number 148 is done.
# Text number 149 is done.
# Text number 150 is done.
# Text number 151 is done.
# Text number 152 is done.
# Text number 153 is done.
# Text number 154 was splited into 2 chunks.
# Text number 154 is done.
# Text number 155 was splited into 2 chunks.
# Text number 155 is done.
# Text number 156 is done.
# Text number 157 is done.
# Text number 158 is done.
# Text number 159 was splited into 2 chunks.
# Text number 159 is done.
# Text number 160 was splited into 2 chunks.
# Text number 160 is done.
# Text number 161 is done.
# Text number 162 is done.
# Text number 163 was splited into 3 chunks.
# Text number 163 is done.
# Text number 164 was splited into 3 chunks.
# Text number 164 is done.
# Text number 165 is done.
# Text number 166 was splited into 2 chunks.
# Text number 166 is done.
# Text number 167 was splited into 2 chunks.
# Text number 167 is done.
# Text number 168 is done.
# Text number 169 is done.
# Text number 170 was splited into 2 chunks.
# Text number 170 is done.
# Text number 171 is done.
# Text number 172 was splited into 2 chunks.
# Text number 172 is done.
# Text number 173 is done.
# Text number 174 is done.
# Text number 175 is done.
# Text number 176 is done.
# Text number 177 is done.
# Text number 178 was splited into 2 chunks.
# Text number 178 is done.
# Text number 179 was splited into 2 chunks.
# Text number 179 is done.
# Text number 180 is done.
# Text number 181 is done.
# Text number 182 is done.
# Text number 183 is done.
# Text number 184 is done.
# Text number 185 is done.
# Text number 186 is done.
# Text number 187 was splited into 2 chunks.
# Text number 187 is done.
# Text number 188 is done.
# Text number 189 is done.
# Text number 190 is done.
# Text number 191 is done.
# Text number 192 is done.
# Text number 193 is done.
# Text number 194 is done.
# Text number 195 is done.
# Text number 196 is done.
# Text number 197 is done.
# Text number 198 is done.
# Text number 199 is done.
# Text number 200 was splited into 2 chunks.
# Text number 200 is done.
# Text number 201 is done.
# Text number 202 is done.
# Text number 203 was splited into 2 chunks.
# Text number 203 is done.
# Text number 204 was splited into 2 chunks.
# Text number 204 is done.
# Text number 205 is done.
# Text number 206 was splited into 2 chunks.
# Text number 206 is done.
# Text number 207 was splited into 2 chunks.
# Text number 207 is done.
# Text number 208 is done.
# Text number 209 was splited into 2 chunks.
# Text number 209 is done.
# Text number 210 is done.
# Text number 211 is done.
# Text number 212 was splited into 2 chunks.
# Text number 212 is done.
# Text number 213 is done.
# Text number 214 is done.
# Text number 215 is done.
# Text number 216 was splited into 2 chunks.
# Text number 216 is done.
# Text number 217 is done.
# Text number 218 is done.
# Text number 219 is done.
# Text number 220 is done.
# Text number 221 was splited into 2 chunks.
# Text number 221 is done.
# Text number 222 is done.
# Text number 223 is done.
# Text number 224 is done.
# Text number 225 is done.
# Text number 226 is done.
# Text number 227 is done.
# Text number 228 is done.
# Text number 229 is done.
# Text number 230 is done.
# Text number 231 is done.
# Text number 232 was splited into 2 chunks.
# Text number 232 is done.
# Text number 233 is done.
# Text number 234 was splited into 2 chunks.
# Text number 234 is done.
# Text number 235 is done.
# Text number 236 is done.
# Text number 237 was splited into 2 chunks.
# Text number 237 is done.
# Text number 238 is done.
# Text number 239 is done.
# Text number 240 is done.
# Text number 241 was splited into 2 chunks.
# Text number 241 is done.
# Text number 242 was splited into 2 chunks.
# Text number 242 is done.
# Text number 243 is done.
# Text number 244 is done.
# Text number 245 is done.
# Text number 246 is done.
# Text number 247 was splited into 2 chunks.
# Text number 247 is done.
# Text number 248 was splited into 2 chunks.
# Text number 248 is done.
# Text number 249 was splited into 2 chunks.
# Text number 249 is done.
# Text number 250 is done.
# Text number 251 was splited into 2 chunks.
# Text number 251 is done.
# Text number 252 was splited into 2 chunks.
# Text number 252 is done.
# Text number 253 was splited into 2 chunks.
# Text number 253 is done.
# Text number 254 is done.
# Text number 255 is done.
# Text number 256 is done.
# Text number 257 was splited into 3 chunks.
# Text number 257 is done.
# Text number 258 is done.
# Text number 259 was splited into 2 chunks.
# Text number 259 is done.
# Text number 260 is done.
# Text number 261 is done.
# Text number 262 was splited into 2 chunks.
# Text number 262 is done.
# Text number 263 was splited into 2 chunks.
# Text number 263 is done.
# Text number 264 is done.
# Text number 265 is done.
# Text number 266 is done.
# Text number 267 is done.
# Text number 268 was splited into 2 chunks.
# Text number 268 is done.
# Text number 269 is done.
# Text number 270 was splited into 3 chunks.
# Text number 270 is done.
# Text number 271 is done.
# Text number 272 was splited into 2 chunks.
# Text number 272 is done.
# Text number 273 is done.
# Text number 274 was splited into 2 chunks.
# Text number 274 is done.
# Text number 275 was splited into 2 chunks.
# Text number 275 is done.
# Text number 276 was splited into 2 chunks.
# Text number 276 is done.
# Text number 277 is done.
# Text number 278 is done.
# Text number 279 was splited into 2 chunks.
# Text number 279 is done.
# Text number 280 is done.
# Text number 281 is done.
# Text number 282 was splited into 2 chunks.
# Text number 282 is done.
# Text number 283 was splited into 2 chunks.
# Text number 283 is done.
# Text number 284 is done.
# Text number 285 was splited into 2 chunks.
# Text number 285 is done.
# Text number 286 is done.
# Text number 287 was splited into 2 chunks.
# Text number 287 is done.
# Text number 288 is done.
# Text number 289 is done.
# Text number 290 is done.
# Text number 291 was splited into 2 chunks.
# Text number 291 is done.
# Text number 292 is done.
# Text number 293 is done.
# Text number 294 is done.
# Text number 295 was splited into 2 chunks.
# Text number 295 is done.
# Text number 296 is done.
# Text number 297 is done.
# Text number 298 is done.
# Text number 299 was splited into 2 chunks.
# Text number 299 is done.
# Text number 300 is done.
# Text number 301 was splited into 2 chunks.
# Text number 301 is done.
# Text number 302 is done.
# Text number 303 was splited into 2 chunks.
# Text number 303 is done.
# Text number 304 was splited into 2 chunks.
# Text number 304 is done.
# Text number 305 was splited into 2 chunks.
# Text number 305 is done.
# Text number 306 is done.
# Text number 307 was splited into 2 chunks.
# Text number 307 is done.
# Text number 308 was splited into 2 chunks.
# Text number 308 is done.
# Text number 309 is done.
# Text number 310 was splited into 3 chunks.
# Text number 310 is done.
# Text number 311 was splited into 2 chunks.
# Text number 311 is done.
# Text number 312 was splited into 2 chunks.
# Text number 312 is done.
# Text number 313 is done.
# Text number 314 was splited into 2 chunks.
# Text number 314 is done.
# Text number 315 is done.
# Text number 316 was splited into 2 chunks.
# Text number 316 is done.
# Text number 317 is done.
# Text number 318 was splited into 3 chunks.
# Text number 318 is done.
# Text number 319 was splited into 2 chunks.
# Text number 319 is done.
# Text number 320 is done.
# Text number 321 was splited into 2 chunks.
# Text number 321 is done.
# Text number 322 was splited into 2 chunks.
# Text number 322 is done.
# Text number 323 is done.
# Text number 324 is done.
# Text number 325 is done.
# Text number 326 is done.
# Text number 327 is done.
# Text number 328 was splited into 3 chunks.
# Text number 328 is done.
# Text number 329 was splited into 3 chunks.
# Text number 329 is done.
# Text number 330 is done.
# Text number 331 is done.
# Text number 332 was splited into 2 chunks.
# Text number 332 is done.
# Text number 333 was splited into 2 chunks.
# Text number 333 is done.
# Text number 334 was splited into 2 chunks.
# Text number 334 is done.
# Text number 335 was splited into 2 chunks.
# Text number 335 is done.
# Text number 336 was splited into 2 chunks.
# Text number 336 is done.
# Text number 337 was splited into 2 chunks.
# Text number 337 is done.
# Text number 338 was splited into 2 chunks.
# Text number 338 is done.
# Text number 339 is done.
# Text number 340 is done.
# Text number 341 is done.
# Text number 342 was splited into 2 chunks.
# Text number 342 is done.
# Text number 343 is done.
# Text number 344 is done.
# Text number 345 is done.
# Text number 346 was splited into 3 chunks.
# Text number 346 is done.
# Text number 347 is done.
# Text number 348 is done.
# Text number 349 is done.
# Text number 350 is done.
# Text number 351 is done.
# Text number 352 is done.
# Text number 353 is done.
# Text number 354 is done.
# Text number 355 is done.
# Text number 356 is done.
# Text number 357 was splited into 2 chunks.
# Text number 357 is done.
# Text number 358 was splited into 2 chunks.
# Text number 358 is done.
# Text number 359 was splited into 2 chunks.
# Text number 359 is done.
# Text number 360 is done.
# Text number 361 is done.
# Text number 362 is done.
# Text number 363 is done.
# Text number 364 is done.
# Text number 365 is done.
# Text number 366 was splited into 2 chunks.
# Text number 366 is done.
# Text number 367 is done.
# Text number 368 is done.
# Text number 369 was splited into 2 chunks.
# Text number 369 is done.
# Text number 370 was splited into 2 chunks.
# Text number 370 is done.
# Text number 371 is done.
# Text number 372 was splited into 2 chunks.
# Text number 372 is done.
# Text number 373 is done.
# Text number 374 is done.
# Text number 375 is done.
# Text number 376 is done.
# Text number 377 is done.
# Text number 378 is done.
# Text number 379 is done.
# Text number 380 was splited into 2 chunks.
# Text number 380 is done.
# Text number 381 is done.
# Text number 382 was splited into 2 chunks.
# Text number 382 is done.
# Text number 383 was splited into 2 chunks.
# Text number 383 is done.
# Text number 384 was splited into 2 chunks.
# Text number 384 is done.
# Text number 385 is done.
# Text number 386 is done.
# Text number 387 was splited into 2 chunks.
# Text number 387 is done.
# Text number 388 is done.
# Text number 389 was splited into 2 chunks.
# Text number 389 is done.
# Text number 390 was splited into 2 chunks.
# Text number 390 is done.
# Text number 391 is done.
# Text number 392 was splited into 2 chunks.
# Text number 392 is done.
# Text number 393 is done.
# Text number 394 is done.
# Text number 395 is done.
# Text number 396 was splited into 2 chunks.
# Text number 396 is done.
# Text number 397 is done.
# Text number 398 was splited into 2 chunks.
# Text number 398 is done.
# Text number 399 was splited into 2 chunks.
# Text number 399 is done.
# Text number 400 was splited into 2 chunks.
# Text number 400 is done.
# Text number 401 is done.
# Text number 402 was splited into 2 chunks.
# Text number 402 is done.
# Text number 403 is done.
# Text number 404 is done.
# Text number 405 is done.
# Text number 406 is done.
# Text number 407 is done.
# Text number 408 is done.
# Text number 409 is done.
# Text number 410 was splited into 2 chunks.
# Text number 410 is done.
# Text number 411 was splited into 2 chunks.
# Text number 411 is done.
# Text number 412 was splited into 3 chunks.
# Text number 412 is done.
# Text number 413 is done.
# Text number 414 was splited into 2 chunks.
# Text number 414 is done.
# Text number 415 was splited into 2 chunks.
# Text number 415 is done.
# Text number 416 was splited into 2 chunks.
# Text number 416 is done.
# Text number 417 is done.
# Text number 418 is done.
# Text number 419 is done.
# Text number 420 is done.
# Text number 421 is done.
# Text number 422 was splited into 3 chunks.
# Text number 422 is done.
# Text number 423 was splited into 2 chunks.
# Text number 423 is done.
# Text number 424 was splited into 2 chunks.
# Text number 424 is done.
# Text number 425 is done.
# Text number 426 is done.
# Text number 427 was splited into 2 chunks.
# Text number 427 is done.
# Text number 428 was splited into 2 chunks.
# Text number 428 is done.
# Text number 429 is done.
# Text number 430 is done.
# Text number 431 is done.
# Text number 432 is done.
# Text number 433 was splited into 2 chunks.
# Text number 433 is done.
# Text number 434 was splited into 2 chunks.
# Text number 434 is done.
# Text number 435 was splited into 2 chunks.
# Text number 435 is done.
# Text number 436 was splited into 2 chunks.
# Text number 436 is done.
# Text number 437 was splited into 2 chunks.
# Text number 437 is done.
# Text number 438 was splited into 2 chunks.
# Text number 438 is done.
# Text number 439 is done.
# Text number 440 was splited into 3 chunks.
# Text number 440 is done.
# Text number 441 was splited into 2 chunks.
# Text number 441 is done.
# Text number 442 was splited into 2 chunks.
# Text number 442 is done.
# Text number 443 was splited into 2 chunks.
# Text number 443 is done.
# Text number 444 is done.
# Text number 445 is done.
# Text number 446 was splited into 2 chunks.
# Text number 446 is done.
# Text number 447 is done.
# Text number 448 is done.
# Text number 449 is done.
# Text number 450 is done.
# Text number 451 is done.
# Text number 452 was splited into 2 chunks.
# Text number 452 is done.
# Text number 453 is done.
# Text number 454 was splited into 2 chunks.
# Text number 454 is done.
# Text number 455 was splited into 2 chunks.
# Text number 455 is done.
# Text number 456 was splited into 2 chunks.
# Text number 456 is done.
# Text number 457 is done.
# Text number 458 was splited into 2 chunks.
# Text number 458 is done.
# Text number 459 is done.
# Text number 460 is done.
# Text number 461 is done.
# Text number 462 was splited into 2 chunks.
# Text number 462 is done.
# Text number 463 was splited into 2 chunks.
# Text number 463 is done.
# Text number 464 was splited into 2 chunks.
# Error occurred for chunck number 2: sequence item 0: expected str instance, NoneType found
# Text number 464 is done.
# Text number 465 is done.
# Text number 466 is done.
# Text number 467 is done.
# Text number 468 was splited into 2 chunks.
# Text number 468 is done.
# Text number 469 is done.
# Text number 470 was splited into 2 chunks.
# Text number 470 is done.
# Text number 471 was splited into 2 chunks.
# Text number 471 is done.
# Text number 472 is done.
# Text number 473 is done.
# Text number 474 is done.
# Text number 475 is done.
# Text number 476 was splited into 2 chunks.
# Text number 476 is done.
# Text number 477 was splited into 2 chunks.
# Text number 477 is done.
# Text number 478 was splited into 2 chunks.
# Text number 478 is done.
# Text number 479 is done.
# Text number 480 is done.
# Text number 481 is done.
# Text number 482 is done.
# Text number 483 was splited into 2 chunks.
# Text number 483 is done.
# Text number 484 is done.
# Text number 485 is done.
# Text number 486 is done.
# Text number 487 was splited into 2 chunks.
# Text number 487 is done.
# Text number 488 is done.
# Text number 489 was splited into 2 chunks.
# Text number 489 is done.
# Text number 490 is done.
# Text number 491 was splited into 2 chunks.
# Text number 491 is done.
# Text number 492 is done.
# Text number 493 was splited into 2 chunks.
# Text number 493 is done.
# Text number 494 is done.
# Text number 495 is done.
# Text number 496 is done.
# Text number 497 was splited into 2 chunks.
# Text number 497 is done.
# Text number 498 is done.
# Text number 499 is done.
# Text number 500 is done.
# Text number 501 was splited into 2 chunks.
# Text number 501 is done.
# Text number 502 was splited into 3 chunks.
# Text number 502 is done.
# Text number 503 was splited into 2 chunks.
# Text number 503 is done.
# Text number 504 was splited into 2 chunks.
# Text number 504 is done.
# Text number 505 is done.
# Text number 506 was splited into 3 chunks.
# Text number 506 is done.
# Text number 507 was splited into 3 chunks.
# Text number 507 is done.
# Text number 508 is done.
# Text number 509 was splited into 2 chunks.
# Text number 509 is done.
# Text number 510 was splited into 2 chunks.
# Text number 510 is done.
# Text number 511 is done.
# Text number 512 was splited into 2 chunks.
# Text number 512 is done.
# Text number 513 was splited into 3 chunks.
# Text number 513 is done.
# Text number 514 is done.
# Text number 515 is done.
# Text number 516 is done.
# Text number 517 was splited into 2 chunks.
# Text number 517 is done.
# Text number 518 is done.
# Text number 519 was splited into 2 chunks.
# Text number 519 is done.
# Text number 520 was splited into 3 chunks.
# Text number 520 is done.
# Text number 521 was splited into 2 chunks.
# Text number 521 is done.
# Text number 522 was splited into 2 chunks.
# Text number 522 is done.
# Text number 523 is done.
# Text number 524 was splited into 2 chunks.
# Text number 524 is done.
# Text number 525 is done.
# Text number 526 was splited into 2 chunks.
# Text number 526 is done.
# Text number 527 was splited into 2 chunks.
# Text number 527 is done.
# Text number 528 is done.
# Text number 529 was splited into 2 chunks.
# Text number 529 is done.
# Text number 530 is done.
# Text number 531 is done.
# Text number 532 was splited into 2 chunks.
# Text number 532 is done.
# Text number 533 was splited into 2 chunks.
# Text number 533 is done.
# Text number 534 is done.
# Text number 535 is done.
# Text number 536 is done.
# Text number 537 is done.
# Text number 538 was splited into 2 chunks.
# Text number 538 is done.
# Text number 539 was splited into 2 chunks.
# Text number 539 is done.
# Text number 540 is done.
# Text number 541 was splited into 2 chunks.
# Text number 541 is done.
# Text number 542 was splited into 2 chunks.
# Text number 542 is done.
# Text number 543 is done.
# Text number 544 is done.
# Text number 545 is done.
# Text number 546 was splited into 2 chunks.
# Text number 546 is done.
# Text number 547 was splited into 2 chunks.
# Text number 547 is done.
# Text number 548 is done.
# Text number 549 was splited into 2 chunks.
# Text number 549 is done.
# Text number 550 was splited into 2 chunks.
# Text number 550 is done.
# Text number 551 was splited into 2 chunks.
# Text number 551 is done.
# Text number 552 was splited into 2 chunks.
# Text number 552 is done.
# Text number 553 was splited into 4 chunks.
# Text number 553 is done.
# Text number 554 was splited into 2 chunks.
# Text number 554 is done.
# Text number 555 was splited into 2 chunks.
# Text number 555 is done.
# Text number 556 is done.
# Text number 557 was splited into 2 chunks.
# Text number 557 is done.
# Text number 558 was splited into 2 chunks.
# Text number 558 is done.
# Text number 559 was splited into 2 chunks.
# Text number 559 is done.
# Text number 560 was splited into 2 chunks.
# Text number 560 is done.
# Text number 561 was splited into 3 chunks.
# Text number 561 is done.
# Text number 562 is done.
# Text number 563 is done.
# Text number 564 was splited into 2 chunks.
# Text number 564 is done.
# Text number 565 is done.
# Text number 566 is done.
# Text number 567 was splited into 2 chunks.
# Text number 567 is done.
# Text number 568 was splited into 2 chunks.
# Text number 568 is done.
# Text number 569 is done.
# Text number 570 was splited into 2 chunks.
# Text number 570 is done.
# Text number 571 is done.
# Text number 572 was splited into 2 chunks.
# Text number 572 is done.
# Text number 573 was splited into 2 chunks.
# Text number 573 is done.
# Text number 574 was splited into 2 chunks.
# Text number 574 is done.
# Text number 575 is done.
# Text number 576 is done.
# Text number 577 is done.
# Text number 578 was splited into 2 chunks.
# Text number 578 is done.
# Text number 579 was splited into 2 chunks.
# Error occurred for chunck number 1: The read operation timed out
# Text number 579 is done.
# Text number 580 is done.
# Text number 581 is done.
# Text number 582 was splited into 2 chunks.
# Text number 582 is done.
# Text number 583 was splited into 2 chunks.
# Text number 583 is done.
# Text number 584 was splited into 2 chunks.
# Text number 584 is done.
# Text number 585 is done.
# Text number 586 was splited into 2 chunks.
# Text number 586 is done.
# Text number 587 is done.
# Text number 588 is done.
# Text number 589 is done.
# Text number 590 was splited into 2 chunks.
# Text number 590 is done.
# Text number 591 is done.
# Text number 592 was splited into 2 chunks.
# Text number 592 is done.
# Text number 593 is done.
# Text number 594 is done.
# Text number 595 is done.
# Text number 596 is done.
# Text number 597 is done.
# Text number 598 was splited into 4 chunks.
# Text number 598 is done.
# Text number 599 is done.
# Text number 600 was splited into 2 chunks.
# Text number 600 is done.
# Text number 601 was splited into 2 chunks.
# Text number 601 is done.
# Text number 602 was splited into 3 chunks.
# Text number 602 is done.
# Text number 603 is done.
# Text number 604 was splited into 2 chunks.
# Text number 604 is done.
# Text number 605 was splited into 2 chunks.
# Text number 605 is done.
# Text number 606 is done.
# Text number 607 was splited into 2 chunks.
# Text number 607 is done.
# Text number 608 is done.
# Text number 609 was splited into 2 chunks.
# Text number 609 is done.
# Text number 610 was splited into 2 chunks.
# Text number 610 is done.
# Text number 611 is done.
# Text number 612 is done.
# Text number 613 was splited into 3 chunks.
# Text number 613 is done.
# Text number 614 is done.
# Text number 615 is done.
# Text number 616 is done.
# Text number 617 is done.
# Text number 618 is done.
# Text number 619 was splited into 2 chunks.
# Text number 619 is done.
# Text number 620 is done.
# Text number 621 was splited into 2 chunks.
# Text number 621 is done.
# Text number 622 was splited into 2 chunks.
# Text number 622 is done.
# Text number 623 is done.
# Text number 624 was splited into 2 chunks.
# Text number 624 is done.
# Text number 625 was splited into 2 chunks.
# Text number 625 is done.
# Text number 626 is done.
# Text number 627 is done.
# Text number 628 was splited into 2 chunks.
# Text number 628 is done.
# Text number 629 is done.
# Text number 630 is done.
# Text number 631 is done.
# Text number 632 was splited into 2 chunks.
# Text number 632 is done.
# Text number 633 was splited into 2 chunks.
# Text number 633 is done.
# Text number 634 was splited into 2 chunks.
# Text number 634 is done.
# Text number 635 was splited into 2 chunks.
# Text number 635 is done.
# Text number 636 was splited into 2 chunks.
# Text number 636 is done.
# Text number 637 was splited into 2 chunks.
# Text number 637 is done.
# Text number 638 is done.
# Text number 639 was splited into 3 chunks.
# Text number 639 is done.
# Text number 640 was splited into 2 chunks.
# Text number 640 is done.
# Text number 641 is done.
# Text number 642 was splited into 2 chunks.
# Text number 642 is done.
# Text number 643 was splited into 2 chunks.
# Text number 643 is done.
# Text number 644 is done.
# Text number 645 was splited into 3 chunks.
# Text number 645 is done.
# Text number 646 was splited into 2 chunks.
# Text number 646 is done.
# Text number 647 is done.
# Text number 648 was splited into 2 chunks.
# Text number 648 is done.
# Text number 649 is done.
# Text number 650 was splited into 2 chunks.
# Text number 650 is done.
# Text number 651 is done.
# Text number 652 was splited into 2 chunks.
# Text number 652 is done.
# Text number 653 is done.
# Text number 654 was splited into 2 chunks.
# Text number 654 is done.
# Text number 655 was splited into 2 chunks.
# Text number 655 is done.
# Text number 656 was splited into 2 chunks.
# Text number 656 is done.
# Text number 657 is done.
# Text number 658 was splited into 2 chunks.
# Text number 658 is done.
# Text number 659 was splited into 2 chunks.
# Text number 659 is done.
# Text number 660 is done.
# Text number 661 was splited into 2 chunks.
# Text number 661 is done.
# Text number 662 was splited into 2 chunks.
# Text number 662 is done.
# Text number 663 is done.
# Text number 664 was splited into 2 chunks.
# Text number 664 is done.
# Text number 665 is done.
# Text number 666 is done.
# Text number 667 was splited into 2 chunks.
# Text number 667 is done.
# Text number 668 was splited into 3 chunks.
# Text number 668 is done.
# Text number 669 was splited into 2 chunks.
# Text number 669 is done.
# Text number 670 is done.
# Text number 671 is done.
# Text number 672 is done.
# Text number 673 was splited into 2 chunks.
# Text number 673 is done.
# Text number 674 was splited into 3 chunks.
# Text number 674 is done.
# Text number 675 was splited into 2 chunks.
# Text number 675 is done.
# Text number 676 was splited into 2 chunks.
# Text number 676 is done.
# Text number 677 was splited into 2 chunks.
# Text number 677 is done.
# Text number 678 was splited into 2 chunks.
# Text number 678 is done.
# Text number 679 was splited into 2 chunks.
# Text number 679 is done.
# Text number 680 was splited into 2 chunks.
# Text number 680 is done.
# Text number 681 is done.
# Text number 682 is done.
# Text number 683 was splited into 2 chunks.
# Text number 683 is done.
# Text number 684 was splited into 3 chunks.
# Text number 684 is done.
# Text number 685 is done.
# Text number 686 was splited into 2 chunks.
# Text number 686 is done.
# Text number 687 is done.
# Text number 688 is done.
# Text number 689 is done.
# Text number 690 is done.
# Text number 691 is done.
# Text number 692 is done.
# Text number 693 was splited into 3 chunks.
# Text number 693 is done.
# Text number 694 was splited into 2 chunks.
# Text number 694 is done.
# Text number 695 is done.
# Text number 696 is done.
# Text number 697 was splited into 2 chunks.
# Text number 697 is done.
# Text number 698 is done.
# Text number 699 was splited into 2 chunks.
# Text number 699 is done.
# Text number 700 is done.
# Text number 701 was splited into 2 chunks.
# Text number 701 is done.
# Text number 702 was splited into 2 chunks.
# Text number 702 is done.
# Text number 703 is done.
# Text number 704 is done.
# Text number 705 was splited into 2 chunks.
# Text number 705 is done.
# Text number 706 is done.
# Text number 707 was splited into 2 chunks.
# Text number 707 is done.
# Text number 708 was splited into 2 chunks.
# Text number 708 is done.
# Text number 709 was splited into 2 chunks.
# Text number 709 is done.
# Text number 710 is done.
# Text number 711 is done.
# Text number 712 was splited into 2 chunks.
# Text number 712 is done.
# Text number 713 is done.
# Text number 714 is done.
# Text number 715 is done.
# Text number 716 is done.
# Text number 717 was splited into 2 chunks.
# Text number 717 is done.
# Text number 718 was splited into 3 chunks.
# Text number 718 is done.
# Text number 719 is done.
# Text number 720 was splited into 2 chunks.
# Text number 720 is done.
# Text number 721 is done.
# Text number 722 is done.
# Text number 723 is done.
# Text number 724 is done.
# Text number 725 is done.
# Text number 726 is done.
# Text number 727 is done.
# Text number 728 is done.
# Text number 729 was splited into 2 chunks.
# Text number 729 is done.
# Text number 730 was splited into 2 chunks.
# Text number 730 is done.
# Text number 731 was splited into 2 chunks.
# Text number 731 is done.
# Text number 732 was splited into 2 chunks.
# Text number 732 is done.
# Text number 733 is done.
# Text number 734 was splited into 2 chunks.
# Text number 734 is done.
# Text number 735 was splited into 2 chunks.
# Text number 735 is done.
# Text number 736 was splited into 2 chunks.
# Text number 736 is done.
# Text number 737 was splited into 2 chunks.
# Text number 737 is done.
# Text number 738 was splited into 2 chunks.
# Text number 738 is done.
# Text number 739 was splited into 2 chunks.
# Text number 739 is done.
# Text number 740 was splited into 2 chunks.
# Text number 740 is done.
# Text number 741 was splited into 2 chunks.
# Text number 741 is done.
# Text number 742 is done.
# Text number 743 is done.
# Text number 744 was splited into 2 chunks.
# Text number 744 is done.
# Text number 745 is done.
# Text number 746 was splited into 2 chunks.
# Text number 746 is done.
# Text number 747 was splited into 2 chunks.
# Text number 747 is done.
# Text number 748 is done.
# Text number 749 is done.
# Text number 750 is done.
# Text number 751 was splited into 2 chunks.
# Text number 751 is done.
# Text number 752 is done.
# Text number 753 was splited into 2 chunks.
# Text number 753 is done.
# Text number 754 was splited into 2 chunks.
# Text number 754 is done.
# Text number 755 is done.
# Text number 756 is done.
# Text number 757 is done.
# Text number 758 was splited into 2 chunks.
# Text number 758 is done.
# Text number 759 was splited into 2 chunks.
# Text number 759 is done.
# Text number 760 is done.
# Text number 761 is done.
# Text number 762 was splited into 2 chunks.
# Text number 762 is done.
# Text number 763 is done.
# Text number 764 is done.
# Text number 765 is done.
# Text number 766 was splited into 4 chunks.
# Text number 766 is done.
# Text number 767 is done.
# Text number 768 is done.
# Text number 769 was splited into 2 chunks.
# Text number 769 is done.
# Text number 770 was splited into 2 chunks.
# Text number 770 is done.
# Text number 771 was splited into 2 chunks.
# Text number 771 is done.
# Text number 772 was splited into 2 chunks.
# Text number 772 is done.
# Text number 773 was splited into 2 chunks.
# Text number 773 is done.
# Text number 774 is done.
# Text number 775 is done.
# Text number 776 is done.
# Text number 777 is done.
# Text number 778 was splited into 2 chunks.
# Text number 778 is done.
# Text number 779 is done.
# Text number 780 is done.
# Text number 781 was splited into 2 chunks.
# Text number 781 is done.
# Text number 782 was splited into 2 chunks.
# Text number 782 is done.
# Text number 783 was splited into 2 chunks.
# Text number 783 is done.
# Text number 784 was splited into 2 chunks.
# Text number 784 is done.
# Text number 785 is done.
# Text number 786 was splited into 2 chunks.
# Text number 786 is done.
# Text number 787 is done.
# Text number 788 is done.
# Text number 789 is done.
# Text number 790 is done.
# Text number 791 was splited into 2 chunks.
# Text number 791 is done.
# Text number 792 was splited into 2 chunks.
# Error occurred for chunck number 2: sequence item 0: expected str instance, NoneType found
# Text number 792 is done.
# Text number 793 was splited into 2 chunks.
# Text number 793 is done.
# Text number 794 was splited into 2 chunks.
# Text number 794 is done.
# Text number 795 was splited into 2 chunks.
# Text number 795 is done.
# Text number 796 is done.
# Text number 797 is done.
# Text number 798 is done.
# Text number 799 was splited into 2 chunks.
# Text number 799 is done.
# Text number 800 is done.
# Text number 801 was splited into 2 chunks.
# Text number 801 is done.
# Text number 802 was splited into 2 chunks.
# Text number 802 is done.
# Text number 803 was splited into 2 chunks.
# Text number 803 is done.
# Text number 804 was splited into 2 chunks.
# Text number 804 is done.
# Text number 805 was splited into 2 chunks.
# Text number 805 is done.
# Text number 806 was splited into 2 chunks.
# Text number 806 is done.
# Text number 807 is done.
# Text number 808 was splited into 2 chunks.
# Text number 808 is done.
# Text number 809 was splited into 2 chunks.
# Text number 809 is done.
# Text number 810 was splited into 2 chunks.
# Text number 810 is done.
# Text number 811 was splited into 2 chunks.
# Text number 811 is done.
# Text number 812 was splited into 2 chunks.
# Text number 812 is done.
# Text number 813 was splited into 2 chunks.
# Text number 813 is done.
# Text number 814 is done.
# Text number 815 is done.
# Text number 816 was splited into 2 chunks.
# Text number 816 is done.
# Text number 817 is done.
# Text number 818 was splited into 3 chunks.
# Text number 818 is done.
# Text number 819 was splited into 2 chunks.
# Text number 819 is done.
# Text number 820 was splited into 2 chunks.
# Text number 820 is done.
# Text number 821 is done.
# Text number 822 is done.
# Text number 823 is done.
# Text number 824 is done.
# Text number 825 is done.
# Text number 826 is done.
# Text number 827 is done.
# Text number 828 is done.
# Text number 829 is done.
# Text number 830 is done.
# Text number 831 was splited into 2 chunks.
# Text number 831 is done.
# Text number 832 is done.
# Text number 833 is done.
# Text number 834 was splited into 2 chunks.
# Text number 834 is done.
# Text number 835 was splited into 2 chunks.
# Text number 835 is done.
# Text number 836 is done.
# Text number 837 was splited into 2 chunks.
# Text number 837 is done.
# Text number 838 was splited into 2 chunks.
# Text number 838 is done.
# Text number 839 is done.
# Text number 840 was splited into 2 chunks.
# Text number 840 is done.
# Text number 841 is done.
# Text number 842 is done.
# Text number 843 is done.
# Text number 844 is done.
# Text number 845 was splited into 2 chunks.
# Text number 845 is done.
# Text number 846 was splited into 2 chunks.
# Text number 846 is done.
# Text number 847 was splited into 2 chunks.
# Text number 847 is done.
# Text number 848 is done.
# Text number 849 is done.
# Text number 850 is done.
# Text number 851 is done.
# Text number 852 is done.
# Text number 853 is done.
# Text number 854 is done.
# Text number 855 is done.
# Text number 856 is done.
# Text number 857 was splited into 2 chunks.
# Text number 857 is done.
# Text number 858 is done.
# Text number 859 was splited into 2 chunks.
# Text number 859 is done.
# Text number 860 was splited into 2 chunks.
# Text number 860 is done.
# Text number 861 was splited into 2 chunks.
# Text number 861 is done.
# Text number 862 is done.
# Text number 863 was splited into 3 chunks.
# Text number 863 is done.
# Text number 864 is done.
# Text number 865 is done.
# Text number 866 was splited into 2 chunks.
# Text number 866 is done.
# Text number 867 was splited into 2 chunks.
# Text number 867 is done.
# Text number 868 is done.
# Text number 869 was splited into 2 chunks.
# Text number 869 is done.
# Text number 870 was splited into 2 chunks.
# Text number 870 is done.
# Text number 871 was splited into 2 chunks.
# Text number 871 is done.
# Text number 872 is done.
# Text number 873 was splited into 2 chunks.
# Text number 873 is done.
# Text number 874 was splited into 2 chunks.
# Text number 874 is done.
# Text number 875 was splited into 2 chunks.
# Text number 875 is done.
# Text number 876 was splited into 2 chunks.
# Text number 876 is done.
# Text number 877 is done.
# Text number 878 is done.
# Text number 879 was splited into 2 chunks.
# Text number 879 is done.
# Text number 880 was splited into 2 chunks.
# Text number 880 is done.
# Text number 881 is done.
# Text number 882 is done.
# Text number 883 is done.
# Text number 884 is done.
# Text number 885 was splited into 2 chunks.
# Text number 885 is done.
# Text number 886 is done.
# Text number 887 is done.
# Text number 888 was splited into 2 chunks.
# Text number 888 is done.
# Text number 889 was splited into 2 chunks.
# Text number 889 is done.
# Text number 890 was splited into 2 chunks.
# Text number 890 is done.
# Text number 891 is done.
# Text number 892 is done.
# Text number 893 is done.
# Text number 894 was splited into 2 chunks.
# Text number 894 is done.
# Text number 895 is done.
# Text number 896 was splited into 2 chunks.
# Text number 896 is done.
# Text number 897 was splited into 2 chunks.
# Text number 897 is done.
# Text number 898 was splited into 2 chunks.
# Text number 898 is done.
# Text number 899 is done.
# Text number 900 is done.
# Text number 901 was splited into 2 chunks.
# Text number 901 is done.
# Text number 902 is done.
# Text number 903 was splited into 2 chunks.
# Text number 903 is done.
# Text number 904 was splited into 2 chunks.
# Text number 904 is done.
# Text number 905 is done.
# Text number 906 was splited into 2 chunks.
# Text number 906 is done.
# Text number 907 is done.
# Text number 908 was splited into 2 chunks.
# Text number 908 is done.
# Text number 909 was splited into 3 chunks.
# Text number 909 is done.
# Text number 910 is done.
# Text number 911 was splited into 2 chunks.
# Text number 911 is done.
# Text number 912 is done.
# Text number 913 is done.
# Text number 914 was splited into 2 chunks.
# Text number 914 is done.
# Text number 915 is done.
# Text number 916 is done.
# Text number 917 is done.
# Text number 918 is done.
# Text number 919 is done.
# Text number 920 is done.
# Text number 921 is done.
# Text number 922 is done.
# Text number 923 was splited into 3 chunks.
# Text number 923 is done.
# Text number 924 is done.
# Text number 925 is done.
# Text number 926 was splited into 2 chunks.
# Text number 926 is done.
# Text number 927 is done.
# Text number 928 was splited into 2 chunks.
# Text number 928 is done.
# Text number 929 was splited into 2 chunks.
# Text number 929 is done.
# Text number 930 was splited into 2 chunks.
# Text number 930 is done.
# Text number 931 was splited into 2 chunks.
# Text number 931 is done.
# Text number 932 is done.
# Text number 933 is done.
# Text number 934 was splited into 2 chunks.
# Text number 934 is done.
# Text number 935 is done.
# Text number 936 was splited into 3 chunks.
# Text number 936 is done.
# Text number 937 was splited into 3 chunks.
# Text number 937 is done.
# Text number 938 is done.
# Text number 939 is done.
# Text number 940 is done.
# Text number 941 is done.
# Text number 942 is done.
# Text number 943 is done.
# Text number 944 is done.
# Text number 945 was splited into 2 chunks.
# Text number 945 is done.
# Text number 946 was splited into 2 chunks.
# Text number 946 is done.
# Text number 947 was splited into 3 chunks.
# Text number 947 is done.
# Text number 948 is done.
# Text number 949 is done.
# Text number 950 was splited into 2 chunks.
# Text number 950 is done.
# Text number 951 is done.
# Text number 952 is done.
# Text number 953 is done.
# Text number 954 was splited into 2 chunks.
# Text number 954 is done.
# Text number 955 is done.
# Text number 956 was splited into 2 chunks.
# Text number 956 is done.
# Text number 957 was splited into 2 chunks.
# Text number 957 is done.
# Text number 958 is done.
# Text number 959 was splited into 2 chunks.
# Text number 959 is done.
# Text number 960 is done.
# Text number 961 was splited into 2 chunks.
# Text number 961 is done.
# Text number 962 is done.
# Text number 963 is done.
# Text number 964 was splited into 2 chunks.
# Text number 964 is done.
# Text number 965 was splited into 2 chunks.
# Text number 965 is done.
# Text number 966 is done.
# Text number 967 is done.
# Text number 968 was splited into 2 chunks.
# Text number 968 is done.
# Text number 969 is done.
# Text number 970 is done.
# Text number 971 was splited into 2 chunks.
# Text number 971 is done.
# Text number 972 is done.
# Text number 973 is done.
# Text number 974 was splited into 2 chunks.
# Text number 974 is done.
# Text number 975 is done.
# Text number 976 was splited into 2 chunks.
# Text number 976 is done.
# Text number 977 is done.
# Text number 978 is done.
# Text number 979 was splited into 2 chunks.
# Text number 979 is done.
# Text number 980 was splited into 2 chunks.
# Text number 980 is done.
# Text number 981 is done.
# Text number 982 was splited into 2 chunks.
# Text number 982 is done.
# Text number 983 is done.
# Text number 984 was splited into 2 chunks.
# Text number 984 is done.
# Text number 985 is done.
# Text number 986 is done.
# Text number 987 was splited into 2 chunks.
# Text number 987 is done.
# Text number 988 is done.
# Text number 989 was splited into 2 chunks.
# Text number 989 is done.
# Text number 990 was splited into 2 chunks.
# Text number 990 is done.
# Text number 991 was splited into 2 chunks.
# Text number 991 is done.
# Text number 992 is done.
# Text number 993 was splited into 3 chunks.
# Text number 993 is done.
# Text number 994 is done.
# Text number 995 is done.
# Text number 996 was splited into 2 chunks.
# Text number 996 is done.
# Text number 997 is done.
# Text number 998 was splited into 2 chunks.
# Text number 998 is done.
# Text number 999 is done.
# Text number 1000 was splited into 2 chunks.
# Text number 1000 is done.
# Text number 1 was splited into 2 chunks.
# Text number 1 is done.
# Text number 2 is done.
# Text number 3 is done.
# Text number 4 is done.
# Text number 5 was splited into 2 chunks.
# Text number 5 is done.
# Text number 6 is done.
# Text number 7 is done.
# Text number 8 is done.
# Text number 9 was splited into 2 chunks.
# Text number 9 is done.
# Text number 10 was splited into 2 chunks.
# Text number 10 is done.
# Text number 11 was splited into 2 chunks.
# Text number 11 is done.
# Text number 12 is done.
# Text number 13 is done.
# Text number 14 was splited into 2 chunks.
# Text number 14 is done.
# Text number 15 is done.
# Text number 16 is done.
# Text number 17 is done.
# Text number 18 was splited into 2 chunks.
# Text number 18 is done.
# Text number 19 is done.
# Text number 20 was splited into 2 chunks.
# Text number 20 is done.
# Text number 21 was splited into 2 chunks.
# Text number 21 is done.
# Text number 22 is done.
# Text number 23 is done.
# Text number 24 was splited into 2 chunks.
# Text number 24 is done.
# Text number 25 was splited into 2 chunks.
# Text number 25 is done.
# Text number 26 is done.
# Text number 27 is done.
# Text number 28 was splited into 2 chunks.
# Text number 28 is done.
# Text number 29 is done.
# Text number 30 is done.
# Text number 31 is done.
# Text number 32 was splited into 2 chunks.
# Text number 32 is done.
# Text number 33 was splited into 2 chunks.
# Text number 33 is done.
# Text number 34 is done.
# Text number 35 is done.
# Text number 36 is done.
# Text number 37 is done.
# Text number 38 is done.
# Text number 39 was splited into 2 chunks.
# Text number 39 is done.
# Text number 40 is done.
# Text number 41 is done.
# Text number 42 is done.
# Text number 43 is done.
# Text number 44 is done.
# Text number 45 is done.
# Text number 46 is done.
# Text number 47 was splited into 2 chunks.
# Text number 47 is done.
# Text number 48 was splited into 2 chunks.
# Text number 48 is done.
# Text number 49 is done.
# Text number 50 is done.
# Text number 51 is done.
# Text number 52 is done.
# Text number 53 is done.
# Text number 54 was splited into 2 chunks.
# Text number 54 is done.
# Text number 55 was splited into 2 chunks.
# Text number 55 is done.
# Text number 56 is done.
# Text number 57 is done.
# Text number 58 is done.
# Text number 59 is done.
# Text number 60 is done.
# Text number 61 is done.
# Text number 62 was splited into 2 chunks.
# Text number 62 is done.
# Text number 63 is done.
# Text number 64 was splited into 2 chunks.
# Text number 64 is done.
# Text number 65 is done.
# Text number 66 was splited into 2 chunks.
# Text number 66 is done.
# Text number 67 is done.
# Text number 68 is done.
# Text number 69 is done.
# Text number 70 was splited into 2 chunks.
# Text number 70 is done.
# Text number 71 was splited into 2 chunks.
# Text number 71 is done.
# Text number 72 was splited into 2 chunks.
# Text number 72 is done.
# Text number 73 was splited into 2 chunks.
# Text number 73 is done.
# Text number 74 is done.
# Text number 75 is done.
# Text number 76 is done.
# Text number 77 is done.
# Text number 78 is done.
# Text number 79 is done.
# Text number 80 was splited into 2 chunks.
# ...
# Text number 611 is done.
# Text number 612 is done.
# Text number 613 is done.
# Text number 614 is done.
# Text number 615 was splited into 2 chunks.
# Text number 615 is done.
# Text number 616 is done.
# Text number 617 is done.
# Text number 618 is done.
# Text number 619 is done.
# Text number 620 was splited into 2 chunks.
# Text number 620 is done.
# Text number 621 is done.
# Text number 622 was splited into 2 chunks.
# Text number 622 is done.
# Text number 623 was splited into 2 chunks.
# Text number 623 is done.
# Text number 624 was splited into 3 chunks.
# Text number 624 is done.
# Text number 625 is done.
# Text number 626 was splited into 2 chunks.
# Text number 626 is done.
# Text number 627 was splited into 2 chunks.
# Text number 627 is done.
# Text number 628 is done.
# Text number 629 was splited into 2 chunks.
# Text number 629 is done.
# Text number 630 is done.
# Text number 631 was splited into 2 chunks.
# Text number 631 is done.
# Text number 632 is done.
# Text number 633 is done.
# Text number 634 is done.
# Text number 635 was splited into 2 chunks.
# Text number 635 is done.
# Text number 636 was splited into 2 chunks.
# Text number 636 is done.
# Text number 637 was splited into 2 chunks.
# Text number 637 is done.
# Text number 638 was splited into 2 chunks.
# Text number 638 is done.
# Text number 639 is done.
# Text number 640 was splited into 2 chunks.
# Text number 640 is done.
# Text number 641 is done.
# Text number 642 was splited into 2 chunks.
# Text number 642 is done.
# Text number 643 is done.
# Text number 644 is done.
# Text number 645 is done.
# Text number 646 was splited into 2 chunks.
# Text number 646 is done.
# Text number 647 was splited into 2 chunks.
# Text number 647 is done.
# Text number 648 was splited into 2 chunks.
# Text number 648 is done.
# Text number 649 is done.
# Text number 650 is done.
# Text number 651 is done.
# Text number 652 is done.
# Text number 653 was splited into 2 chunks.
# Text number 653 is done.
# Text number 654 was splited into 2 chunks.
# Text number 654 is done.
# Text number 655 was splited into 2 chunks.
# Text number 655 is done.
# Text number 656 is done.
# Text number 657 was splited into 2 chunks.
# Text number 657 is done.
# Text number 658 is done.
# Text number 659 is done.
# Text number 660 was splited into 2 chunks.
# Text number 660 is done.
# Text number 661 is done.
# Text number 662 is done.
# Text number 663 is done.
# Text number 664 was splited into 2 chunks.
# Text number 664 is done.
# Text number 665 is done.
# Text number 666 is done.
# Text number 667 is done.
# Text number 668 is done.
# Text number 669 is done.
# Text number 670 was splited into 2 chunks.
# Text number 670 is done.
# Text number 671 is done.
# Text number 672 is done.
# Text number 673 is done.
# Text number 674 is done.
# Text number 675 is done.
# Text number 676 is done.
# Text number 677 was splited into 2 chunks.
# Text number 677 is done.
# Text number 678 was splited into 2 chunks.
# Text number 678 is done.
# Text number 679 is done.
# Text number 680 is done.
# Text number 681 was splited into 2 chunks.
# Text number 681 is done.
# Text number 682 is done.
# Text number 683 is done.
# Text number 684 was splited into 2 chunks.
# Text number 684 is done.
# Text number 685 was splited into 2 chunks.
# Text number 685 is done.
# Text number 686 is done.
# Text number 687 is done.
# Text number 688 is done.
# Text number 689 is done.
# Text number 690 is done.
# Text number 691 was splited into 2 chunks.
# Text number 691 is done.
# Text number 692 was splited into 2 chunks.
# Text number 692 is done.
# Text number 693 is done.
# Text number 694 is done.
# Text number 695 is done.
# Text number 696 is done.
# Text number 697 was splited into 2 chunks.
# Text number 697 is done.
# Text number 698 is done.
# Text number 699 is done.
# Text number 700 is done.
# Text number 701 is done.
# Text number 702 is done.
# Text number 703 is done.
# Text number 704 is done.
# Text number 705 is done.
# Text number 706 is done.
# Text number 707 is done.
# Text number 708 is done.
# Text number 709 is done.
# Text number 710 was splited into 2 chunks.
# Text number 710 is done.
# Text number 711 is done.
# Text number 712 was splited into 2 chunks.
# Text number 712 is done.
# Text number 713 is done.
# Text number 714 was splited into 2 chunks.
# Text number 714 is done.
# Text number 715 was splited into 2 chunks.
# Text number 715 is done.
# Text number 716 is done.
# Text number 717 is done.
# Text number 718 is done.
# Text number 719 was splited into 2 chunks.
# Text number 719 is done.
# Text number 720 was splited into 2 chunks.
# Text number 720 is done.
# Text number 721 is done.
# Text number 722 is done.
# Text number 723 is done.
# Text number 724 was splited into 2 chunks.
# Text number 724 is done.
# Text number 725 is done.
# Text number 726 is done.
# Text number 727 is done.
# Text number 728 is done.
# Text number 729 is done.
# Text number 730 is done.
# Text number 731 was splited into 2 chunks.
# Text number 731 is done.
# Text number 732 is done.
# Text number 733 was splited into 3 chunks.
# Text number 733 is done.
# Text number 734 is done.
# Text number 735 is done.
# Text number 736 is done.
# Text number 737 was splited into 2 chunks.
# Text number 737 is done.
# Text number 738 is done.
# Text number 739 is done.
# Text number 740 is done.
# Text number 741 is done.
# Text number 742 is done.
# Text number 743 is done.
# Text number 744 is done.
# Text number 745 was splited into 2 chunks.
# Text number 745 is done.
# Text number 746 was splited into 2 chunks.
# Text number 746 is done.
# Text number 747 was splited into 3 chunks.
# Text number 747 is done.
# Text number 748 is done.
# Text number 749 is done.
# Text number 750 was splited into 2 chunks.
# Text number 750 is done.
# Text number 751 is done.
# Text number 752 is done.
# Text number 753 is done.
# Text number 754 is done.
# Text number 755 is done.
# Text number 756 was splited into 2 chunks.
# Text number 756 is done.
# Text number 757 is done.
# Text number 758 is done.
# Text number 759 was splited into 2 chunks.
# Text number 759 is done.
# Text number 760 was splited into 2 chunks.
# Text number 760 is done.
# Text number 761 was splited into 2 chunks.
# Text number 761 is done.
# Text number 762 was splited into 2 chunks.
# Text number 762 is done.
# Text number 763 was splited into 2 chunks.
# Text number 763 is done.
# Text number 764 is done.
# Text number 765 is done.
# Text number 766 is done.
# Text number 767 was splited into 2 chunks.
# Text number 767 is done.
# Text number 768 was splited into 2 chunks.
# Text number 768 is done.
# Text number 769 was splited into 2 chunks.
# Text number 769 is done.
# Text number 770 is done.
# Text number 771 was splited into 2 chunks.
# Text number 771 is done.
# Text number 772 is done.
# Text number 773 was splited into 2 chunks.
# Text number 773 is done.
# Text number 774 was splited into 2 chunks.
# Text number 774 is done.
# Text number 775 is done.
# Text number 776 is done.
# Text number 777 is done.
# Text number 778 was splited into 2 chunks.
# Text number 778 is done.
# Text number 779 is done.
# Text number 780 is done.
# Text number 781 is done.
# Text number 782 was splited into 2 chunks.
# Text number 782 is done.
# Text number 783 is done.
# Text number 784 is done.
# Text number 785 was splited into 2 chunks.
# Text number 785 is done.
# Text number 786 is done.
# Text number 787 is done.
# Text number 788 was splited into 3 chunks.
# Text number 788 is done.
# Text number 789 was splited into 2 chunks.
# Text number 789 is done.
# Text number 790 is done.
# Text number 791 is done.
# Text number 792 is done.
# Text number 793 is done.
# Text number 794 is done.
# Text number 795 is done.
# Text number 796 is done.
# Text number 797 is done.
# Text number 798 was splited into 2 chunks.
# Text number 798 is done.
# Text number 799 is done.
# Text number 800 was splited into 2 chunks.
# Text number 800 is done.
# Text number 801 is done.
# Text number 802 is done.
# Text number 803 is done.
# Text number 804 was splited into 2 chunks.
# Text number 804 is done.
# Text number 805 is done.
# Text number 806 is done.
# Text number 807 is done.
# Text number 808 was splited into 3 chunks.
# Text number 808 is done.
# Text number 809 is done.
# Text number 810 is done.
# Text number 811 is done.
# Text number 812 was splited into 2 chunks.
# Text number 812 is done.
# Text number 813 is done.
# Text number 814 was splited into 2 chunks.
# Text number 814 is done.
# Text number 815 is done.
# Text number 816 was splited into 2 chunks.
# Text number 816 is done.
# Text number 817 is done.
# Text number 818 is done.
# Text number 819 was splited into 2 chunks.
# Text number 819 is done.
# Text number 820 is done.
# Text number 821 was splited into 2 chunks.
# Text number 821 is done.
# Text number 822 is done.
# Text number 823 is done.
# Text number 824 is done.
# Text number 825 is done.
# Text number 826 is done.
# Text number 827 was splited into 2 chunks.
# Text number 827 is done.
# Text number 828 is done.
# Text number 829 is done.
# Text number 830 was splited into 2 chunks.
# Text number 830 is done.
# Text number 831 is done.
# Text number 832 was splited into 2 chunks.
# Text number 832 is done.
# Text number 833 was splited into 2 chunks.
# Text number 833 is done.
# Text number 834 was splited into 2 chunks.
# Text number 834 is done.
# Text number 835 was splited into 2 chunks.
# Text number 835 is done.
# Text number 836 was splited into 2 chunks.
# Text number 836 is done.
# Text number 837 is done.
# Text number 838 is done.
# Text number 839 was splited into 2 chunks.
# Text number 839 is done.
# Text number 840 is done.
# Text number 841 is done.
# Text number 842 was splited into 2 chunks.
# Text number 842 is done.
# Text number 843 was splited into 2 chunks.
# Text number 843 is done.
# Text number 844 is done.
# Text number 845 was splited into 2 chunks.
# Text number 845 is done.
# Text number 846 is done.
# Text number 847 was splited into 2 chunks.
# Text number 847 is done.
# Text number 848 was splited into 2 chunks.
# Text number 848 is done.
# Text number 849 is done.
# Text number 850 was splited into 2 chunks.
# Text number 850 is done.
# Text number 851 is done.
# Text number 852 is done.
# Text number 853 was splited into 2 chunks.
# Text number 853 is done.
# Text number 854 is done.
# Text number 855 is done.
# Text number 856 is done.
# Text number 857 is done.
# Text number 858 is done.
# Text number 859 was splited into 2 chunks.
# Text number 859 is done.
# Text number 860 is done.
# Text number 861 is done.
# Text number 862 is done.
# Text number 863 was splited into 2 chunks.
# Text number 863 is done.
# Text number 864 is done.
# Text number 865 was splited into 2 chunks.
# Text number 865 is done.
# Text number 866 was splited into 2 chunks.
# Text number 866 is done.
# Text number 867 is done.
# Text number 868 was splited into 2 chunks.
# Text number 868 is done.
# Text number 869 is done.
# Text number 870 was splited into 2 chunks.
# Text number 870 is done.
# Text number 871 is done.
# Text number 872 was splited into 3 chunks.
# Text number 872 is done.
# Text number 873 was splited into 2 chunks.
# Text number 873 is done.
# Text number 874 is done.
# Text number 875 was splited into 2 chunks.
# Text number 875 is done.
# Text number 876 is done.
# Text number 877 was splited into 2 chunks.
# Text number 877 is done.
# Text number 878 is done.
# Text number 879 is done.
# Text number 880 is done.
# Text number 881 is done.
# Text number 882 is done.
# Text number 883 was splited into 2 chunks.
# Text number 883 is done.
# Text number 884 was splited into 2 chunks.
# Text number 884 is done.
# Text number 885 is done.
# Text number 886 is done.
# Text number 887 is done.
# Text number 888 is done.
# Text number 889 was splited into 2 chunks.
# Text number 889 is done.
# Text number 890 was splited into 2 chunks.
# Text number 890 is done.
# Text number 891 was splited into 2 chunks.
# Text number 891 is done.
# Text number 892 was splited into 2 chunks.
# Text number 892 is done.
# Text number 893 was splited into 2 chunks.
# Text number 893 is done.
# Text number 894 was splited into 3 chunks.
# Text number 894 is done.
# Text number 895 is done.
# Text number 896 is done.
# Text number 897 is done.
# Text number 898 is done.
# Text number 899 is done.
# Text number 900 is done.
# Text number 901 is done.
# Text number 902 is done.
# Text number 903 was splited into 2 chunks.
# Text number 903 is done.
# Text number 904 is done.
# Text number 905 is done.
# Text number 906 is done.
# Text number 907 was splited into 2 chunks.
# Text number 907 is done.
# Text number 908 is done.
# Text number 909 was splited into 2 chunks.
# Text number 909 is done.
# Text number 910 is done.
# Text number 911 is done.
# Text number 912 was splited into 2 chunks.
# Text number 912 is done.
# Text number 913 was splited into 2 chunks.
# Text number 913 is done.
# Text number 914 is done.
# Text number 915 is done.
# Text number 916 is done.
# Text number 917 is done.
# Text number 918 is done.
# Text number 919 is done.
# Text number 920 is done.
# Text number 921 is done.
# Text number 922 was splited into 2 chunks.
# Text number 922 is done.
# Text number 923 is done.
# Text number 924 was splited into 2 chunks.
# Text number 924 is done.
# Text number 925 is done.
# Text number 926 is done.
# Text number 927 was splited into 3 chunks.
# Text number 927 is done.
# Text number 928 was splited into 2 chunks.
# Text number 928 is done.
# Text number 929 was splited into 2 chunks.
# Text number 929 is done.
# Text number 930 is done.
# Text number 931 is done.
# Text number 932 is done.
# Text number 933 is done.
# Text number 934 was splited into 3 chunks.
# Text number 934 is done.
# Text number 935 was splited into 2 chunks.
# Text number 935 is done.
# Text number 936 was splited into 2 chunks.
# Text number 936 is done.
# Text number 937 is done.
# Text number 938 is done.
# Text number 939 is done.
# Text number 940 is done.
# Text number 941 is done.
# Text number 942 was splited into 2 chunks.
# Text number 942 is done.
# Text number 943 is done.
# Text number 944 is done.
# Text number 945 is done.
# Text number 946 is done.
# Text number 947 is done.
# Text number 948 is done.
# Text number 949 is done.
# Text number 950 was splited into 2 chunks.
# Text number 950 is done.
# Text number 951 was splited into 2 chunks.
# Text number 951 is done.
# Text number 952 was splited into 2 chunks.
# Text number 952 is done.
# Text number 953 was splited into 2 chunks.
# Text number 953 is done.
# Text number 954 is done.
# Text number 955 was splited into 2 chunks.
# Text number 955 is done.
# Text number 956 is done.
# Text number 957 was splited into 2 chunks.
# Text number 957 is done.
# Text number 958 is done.
# Text number 959 is done.
# Text number 960 is done.
# Text number 961 is done.
# Text number 962 is done.
# Text number 963 is done.
# Text number 964 was splited into 2 chunks.
# Text number 964 is done.
# Text number 965 is done.
# Text number 966 is done.
# Text number 967 was splited into 2 chunks.
# Text number 967 is done.
# Text number 968 is done.
# Text number 969 was splited into 2 chunks.
# Text number 969 is done.
# Text number 970 is done.
# Text number 971 was splited into 2 chunks.
# Text number 971 is done.
# Text number 972 was splited into 2 chunks.
# Text number 972 is done.
# Text number 973 was splited into 2 chunks.
# Text number 973 is done.
# Text number 974 was splited into 2 chunks.
# Text number 974 is done.
# Text number 975 is done.
# Text number 976 was splited into 3 chunks.
# Text number 976 is done.
# Text number 977 is done.
# Text number 978 is done.
# Text number 979 is done.
# Text number 980 is done.
# Text number 981 is done.
# Text number 982 was splited into 2 chunks.
# Text number 982 is done.
# Text number 983 is done.
# Text number 984 is done.
# Text number 985 is done.
# Text number 986 is done.
# Text number 987 is done.
# Text number 988 was splited into 2 chunks.
# Text number 988 is done.
# Text number 989 was splited into 2 chunks.
# Text number 989 is done.
# Text number 990 is done.
# Text number 991 is done.
# Text number 992 was splited into 2 chunks.
# Text number 992 is done.
# Text number 993 was splited into 2 chunks.
# Text number 993 is done.
# Text number 994 is done.
# Text number 995 was splited into 2 chunks.
# Text number 995 is done.
# Text number 996 was splited into 3 chunks.
# Text number 996 is done.
# Text number 997 was splited into 2 chunks.
# Text number 997 is done.
# Text number 998 is done.
# Text number 999 is done.
# Text number 1000 is done.
# Lenght Of Positive Reviews After Augmentation:  2000
# Lenght Of Negative Reviews Before Augmentation:  2000

# %%
# Write the augmented reviews to text files
def write_reviews_to_files(reviews, directory):
    # Create the directory if it doesn't exist
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # Write each review to a separate text file
    for i, review in enumerate(reviews, start=1):
        filename = os.path.join(directory, f"review_{i}.txt")
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(review)

# %%
# Create the main directory
main_directory = 'Augmented_Dataset'
os.makedirs(main_directory, exist_ok=True)

# Create subdirectories for positive and negative reviews
pos_directory = os.path.join(main_directory, 'pos')
neg_directory = os.path.join(main_directory, 'neg')
os.makedirs(pos_directory, exist_ok=True)
os.makedirs(neg_directory, exist_ok=True)

# %%
# Write positive and negative reviews to files
write_reviews_to_files(pos_reviews, pos_directory)
write_reviews_to_files(neg_reviews, neg_directory)

print("Reviews have been written to files successfully!!")
# Out:
# Reviews have been written to files successfully!!
